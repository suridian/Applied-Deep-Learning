# %% [markdown]
# <a href="https://colab.research.google.com/github/suridian/Applied-Deep-Learning/blob/main/AlexNet(BatchNormalization_dan_DenseLayer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.2.0
# Out:
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2 MB)
#      |████████████████████████████████| 516.2 MB 4.1 kB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.17.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 45.2 MB/s
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      |████████████████████████████████| 454 kB 56.0 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.14.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.4.1)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 43.3 MB/s
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.44.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.37.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.21.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.3.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.2.0)
# Installing collected packages: tensorflow-estimator, tensorboard, h5py, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# Successfully installed gast-0.3.3 h5py-2.10.0 tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

training_images = training_images[:1000]
training_labels = training_labels[:1000]
test_images = test_images[:100]
test_labels = test_labels[:100]

training_images = tf.map_fn(lambda i: tf.stack([i]*3, axis=-1), training_images).numpy()
test_images = tf.map_fn(lambda i: tf.stack([i]*3, axis=-1), test_images).numpy()

training_images = tf.image.resize(training_images, [224, 224]).numpy()
test_images = tf.image.resize(test_images, [224, 224]).numpy()

training_images = training_images.reshape(1000, 224, 224, 3)
training_images = training_images / 255.0
test_images = test_images.reshape(100, 224, 224, 3)
test_images = test_images / 255.0

training_labels = tf.keras.utils.to_categorical(training_labels, num_classes=10)
test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=10)

num_len_train = int(0.8 * len(training_images))

ttraining_images = training_images[:num_len_train]
ttraining_labels = training_labels[:num_len_train]

valid_images = training_images[num_len_train:]
valid_labels = training_labels[num_len_train:]

training_images = ttraining_images
training_labels = ttraining_labels
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

training_images = training_images[:1000]
training_labels = training_labels[:1000]
test_images = test_images[:100]
test_labels = test_labels[:100]

training_images = tf.map_fn(lambda i: tf.stack([i]*3, axis=-1), training_images).numpy()
test_images = tf.map_fn(lambda i: tf.stack([i]*3, axis=-1), test_images).numpy()

training_images = tf.image.resize(training_images, [224, 224]).numpy()
test_images = tf.image.resize(test_images, [224, 224]).numpy()

training_images = training_images.reshape(1000, 224, 224, 3)
training_images = training_images / 255.0
test_images = test_images.reshape(100, 224, 224, 3)
test_images = test_images / 255.0

training_labels = tf.keras.utils.to_categorical(training_labels, num_classes=10)
test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=10)

num_len_train = int(0.8 * len(training_images))

ttraining_images = training_images[:num_len_train]
ttraining_labels = training_labels[:num_len_train]

valid_images = training_images[num_len_train:]
valid_labels = training_labels[num_len_train:]

training_images = ttraining_images
training_labels = ttraining_labels
model = tf.keras.models.Sequential([
		tf.keras.layers.Conv2D(96, (11, 11), strides=(4, 4), activation='relu', \
			kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01), \
			input_shape=(224, 224, 3)),

    tf.keras.layers.BatchNormalization(),
	
		tf.keras.layers.MaxPooling2D(3, strides=2),
		
		tf.keras.layers.Conv2D(256, (5, 5), activation='relu', \
			kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01), \
			bias_initializer='ones'),
		
		tf.keras.layers.MaxPooling2D(3, strides=2),
		
		tf.keras.layers.Conv2D(384, (3, 3), activation='relu', \
			kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01)),
		
		tf.keras.layers.Conv2D(384, (3, 3), activation='relu', \
			kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01), \
			bias_initializer='ones'),
		
		tf.keras.layers.Conv2D(384, (3, 3), activation='relu', \
			kernel_initializer=tf.random_normal_initializer(mean=0.0, stddev=0.01), \
			bias_initializer='ones'),
		
		tf.keras.layers.MaxPooling2D(3, strides=2),
    		
		tf.keras.layers.Flatten(),
		
		tf.keras.layers.Dense(4096, kernel_initializer=\
		                      tf.random_normal_initializer(mean=0.0, stddev=0.01), \
				      bias_initializer='ones'),
		
		tf.keras.layers.Dropout(0.5),
		
		tf.keras.layers.Dense(4096, kernel_initializer=\
		                      tf.random_normal_initializer(mean=0.0, stddev=0.01), \
				      bias_initializer='ones'),
		
		tf.keras.layers.Dropout(0.5),
		
		tf.keras.layers.Dense(10, activation='softmax', \
				      kernel_initializer= \
				      tf.random_normal_initializer(mean=0.0, stddev=0.01))
	])


model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), \
              loss='categorical_crossentropy', \
	      metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy(5)])

print(model.summary())

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', \
                                            	factor=0.1, patience=1, \
						min_lr=0.00001)

model.fit(training_images, training_labels, batch_size=128, \
          validation_data=(valid_images, valid_labels), \
	  epochs=90, callbacks=[reduce_lr])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 54, 54, 96)        34944
# _________________________________________________________________
# batch_normalization (BatchNo (None, 54, 54, 96)        384
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 26, 26, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         1327488
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 384)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 384)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1576960
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 22,589,322
# Trainable params: 22,589,130
# Non-trainable params: 192
# _________________________________________________________________
# None
# Epoch 1/90
# 7/7 [==============================] - 49s 7s/step - loss: 15.0826 - accuracy: 0.1063 - top_k_categorical_accuracy: 0.5275 - val_loss: 74.3838 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 0.5350 - lr: 0.0100
# Epoch 2/90
# 7/7 [==============================] - 49s 7s/step - loss: 70.5054 - accuracy: 0.0862 - top_k_categorical_accuracy: 0.5987 - val_loss: 38.8503 - val_accuracy: 0.1050 - val_top_k_categorical_accuracy: 0.4450 - lr: 0.0100
# Epoch 3/90
# 7/7 [==============================] - 47s 7s/step - loss: 3126.4050 - accuracy: 0.1013 - top_k_categorical_accuracy: 0.8425 - val_loss: 10443.7080 - val_accuracy: 0.0900 - val_top_k_categorical_accuracy: 1.0000 - lr: 0.0100
# Epoch 4/90
# 7/7 [==============================] - 48s 7s/step - loss: 15724.9004 - accuracy: 0.1088 - top_k_categorical_accuracy: 1.0000 - val_loss: 15204.2363 - val_accuracy: 0.1550 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-03
# Epoch 5/90
# 7/7 [==============================] - 47s 7s/step - loss: 16715.8926 - accuracy: 0.1088 - top_k_categorical_accuracy: 1.0000 - val_loss: 30835.8906 - val_accuracy: 0.0900 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 6/90
# 7/7 [==============================] - 47s 7s/step - loss: 55925.9883 - accuracy: 0.1225 - top_k_categorical_accuracy: 1.0000 - val_loss: 79420.2812 - val_accuracy: 0.0900 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 7/90
# 7/7 [==============================] - 48s 7s/step - loss: 72891.6172 - accuracy: 0.1225 - top_k_categorical_accuracy: 1.0000 - val_loss: 51248.1367 - val_accuracy: 0.0900 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 8/90
# 7/7 [==============================] - 47s 7s/step - loss: 29364.2754 - accuracy: 0.1112 - top_k_categorical_accuracy: 1.0000 - val_loss: 14429.0674 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 9/90
# 7/7 [==============================] - 47s 7s/step - loss: 19907.3633 - accuracy: 0.0975 - top_k_categorical_accuracy: 1.0000 - val_loss: 19207.6289 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 10/90
# 7/7 [==============================] - 47s 7s/step - loss: 23374.4453 - accuracy: 0.0950 - top_k_categorical_accuracy: 1.0000 - val_loss: 18908.0879 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 11/90
# 7/7 [==============================] - 47s 7s/step - loss: 21799.4707 - accuracy: 0.0838 - top_k_categorical_accuracy: 1.0000 - val_loss: 16655.6680 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 12/90
# 7/7 [==============================] - 47s 7s/step - loss: 18099.0742 - accuracy: 0.0962 - top_k_categorical_accuracy: 1.0000 - val_loss: 13190.0820 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 13/90
# 7/7 [==============================] - 47s 7s/step - loss: 13537.4160 - accuracy: 0.0887 - top_k_categorical_accuracy: 1.0000 - val_loss: 9257.3311 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 14/90
# 7/7 [==============================] - 47s 7s/step - loss: 11890.3828 - accuracy: 0.0950 - top_k_categorical_accuracy: 1.0000 - val_loss: 7590.7329 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 15/90
# 7/7 [==============================] - 47s 7s/step - loss: 11274.4951 - accuracy: 0.0962 - top_k_categorical_accuracy: 1.0000 - val_loss: 8814.6680 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 16/90
# 7/7 [==============================] - 47s 7s/step - loss: 10690.5303 - accuracy: 0.1013 - top_k_categorical_accuracy: 1.0000 - val_loss: 8218.0742 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 17/90
# 7/7 [==============================] - 47s 7s/step - loss: 10070.5312 - accuracy: 0.0938 - top_k_categorical_accuracy: 1.0000 - val_loss: 7069.1948 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 18/90
# 7/7 [==============================] - 49s 7s/step - loss: 9580.0801 - accuracy: 0.0825 - top_k_categorical_accuracy: 1.0000 - val_loss: 6744.6968 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 19/90
# 7/7 [==============================] - 48s 7s/step - loss: 8994.7617 - accuracy: 0.1125 - top_k_categorical_accuracy: 1.0000 - val_loss: 6595.3779 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 20/90
# 7/7 [==============================] - 48s 7s/step - loss: 8668.8320 - accuracy: 0.0913 - top_k_categorical_accuracy: 1.0000 - val_loss: 6341.3032 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 21/90
# 7/7 [==============================] - 48s 7s/step - loss: 8083.1646 - accuracy: 0.1013 - top_k_categorical_accuracy: 1.0000 - val_loss: 5884.8452 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 22/90
# 7/7 [==============================] - 47s 7s/step - loss: 8103.3008 - accuracy: 0.0875 - top_k_categorical_accuracy: 1.0000 - val_loss: 5734.7720 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 23/90
# 7/7 [==============================] - 47s 7s/step - loss: 7639.3130 - accuracy: 0.1037 - top_k_categorical_accuracy: 1.0000 - val_loss: 5288.2144 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 24/90
# 7/7 [==============================] - 47s 7s/step - loss: 7508.6387 - accuracy: 0.0875 - top_k_categorical_accuracy: 1.0000 - val_loss: 5158.4673 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 25/90
# 7/7 [==============================] - 47s 7s/step - loss: 7190.8687 - accuracy: 0.0887 - top_k_categorical_accuracy: 1.0000 - val_loss: 4750.1133 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 26/90
# 7/7 [==============================] - 47s 7s/step - loss: 6478.4150 - accuracy: 0.1238 - top_k_categorical_accuracy: 1.0000 - val_loss: 4591.2324 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 27/90
# 7/7 [==============================] - 47s 7s/step - loss: 6094.6807 - accuracy: 0.1037 - top_k_categorical_accuracy: 1.0000 - val_loss: 4349.7476 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 28/90
# 7/7 [==============================] - 47s 7s/step - loss: 5914.8188 - accuracy: 0.1150 - top_k_categorical_accuracy: 1.0000 - val_loss: 4081.4695 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 29/90
# 7/7 [==============================] - 49s 7s/step - loss: 5727.5908 - accuracy: 0.0938 - top_k_categorical_accuracy: 1.0000 - val_loss: 3815.2998 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 30/90
# 7/7 [==============================] - 47s 7s/step - loss: 5256.0288 - accuracy: 0.1050 - top_k_categorical_accuracy: 1.0000 - val_loss: 3504.2341 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 31/90
# 7/7 [==============================] - 47s 7s/step - loss: 5202.2812 - accuracy: 0.1013 - top_k_categorical_accuracy: 1.0000 - val_loss: 3556.5376 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 32/90
# 7/7 [==============================] - 47s 7s/step - loss: 5074.0283 - accuracy: 0.0938 - top_k_categorical_accuracy: 1.0000 - val_loss: 3187.6477 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 33/90
# 7/7 [==============================] - 47s 7s/step - loss: 4515.9370 - accuracy: 0.1037 - top_k_categorical_accuracy: 1.0000 - val_loss: 2931.0063 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 34/90
# 7/7 [==============================] - 47s 7s/step - loss: 4592.5566 - accuracy: 0.0950 - top_k_categorical_accuracy: 1.0000 - val_loss: 2706.5681 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 35/90
# 7/7 [==============================] - 47s 7s/step - loss: 4218.8467 - accuracy: 0.1000 - top_k_categorical_accuracy: 1.0000 - val_loss: 2260.7749 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 36/90
# 7/7 [==============================] - 47s 7s/step - loss: 3966.5415 - accuracy: 0.1025 - top_k_categorical_accuracy: 1.0000 - val_loss: 2358.5728 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 37/90
# 7/7 [==============================] - 47s 7s/step - loss: 3828.6406 - accuracy: 0.1050 - top_k_categorical_accuracy: 1.0000 - val_loss: 2292.4231 - val_accuracy: 0.0700 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 38/90
# 7/7 [==============================] - 47s 7s/step - loss: 3705.5801 - accuracy: 0.1200 - top_k_categorical_accuracy: 0.9987 - val_loss: 2080.9658 - val_accuracy: 0.0700 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 39/90
# 7/7 [==============================] - 47s 7s/step - loss: 3846.6360 - accuracy: 0.1013 - top_k_categorical_accuracy: 0.9987 - val_loss: 2089.5249 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 40/90
# 7/7 [==============================] - 49s 7s/step - loss: 3669.3289 - accuracy: 0.0862 - top_k_categorical_accuracy: 0.9987 - val_loss: 2231.2925 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 41/90
# 7/7 [==============================] - 48s 7s/step - loss: 3681.8396 - accuracy: 0.1025 - top_k_categorical_accuracy: 1.0000 - val_loss: 2038.8582 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 42/90
# 7/7 [==============================] - 48s 7s/step - loss: 3892.9546 - accuracy: 0.0862 - top_k_categorical_accuracy: 1.0000 - val_loss: 1968.9944 - val_accuracy: 0.1550 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 43/90
# 7/7 [==============================] - 48s 7s/step - loss: 3169.6631 - accuracy: 0.1088 - top_k_categorical_accuracy: 1.0000 - val_loss: 1902.7969 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 44/90
# 7/7 [==============================] - 47s 7s/step - loss: 3363.5103 - accuracy: 0.0962 - top_k_categorical_accuracy: 1.0000 - val_loss: 1850.1222 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/90
# 7/7 [==============================] - 47s 7s/step - loss: 3431.0259 - accuracy: 0.0950 - top_k_categorical_accuracy: 1.0000 - val_loss: 1943.7367 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 46/90
# 7/7 [==============================] - 48s 7s/step - loss: 3241.1409 - accuracy: 0.1100 - top_k_categorical_accuracy: 1.0000 - val_loss: 1747.8154 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 47/90
# 7/7 [==============================] - 48s 7s/step - loss: 3305.1394 - accuracy: 0.0938 - top_k_categorical_accuracy: 1.0000 - val_loss: 1686.0441 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 48/90
# 7/7 [==============================] - 48s 7s/step - loss: 3200.1819 - accuracy: 0.1025 - top_k_categorical_accuracy: 1.0000 - val_loss: 1704.7582 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 49/90
# 7/7 [==============================] - 48s 7s/step - loss: 3005.3384 - accuracy: 0.1100 - top_k_categorical_accuracy: 1.0000 - val_loss: 1714.5920 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 50/90
# 7/7 [==============================] - 48s 7s/step - loss: 3179.3035 - accuracy: 0.0938 - top_k_categorical_accuracy: 1.0000 - val_loss: 1443.2830 - val_accuracy: 0.1550 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 51/90
# 7/7 [==============================] - 48s 7s/step - loss: 3096.9497 - accuracy: 0.1037 - top_k_categorical_accuracy: 1.0000 - val_loss: 1592.1479 - val_accuracy: 0.1000 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 52/90
# 7/7 [==============================] - 48s 7s/step - loss: 3035.4148 - accuracy: 0.1050 - top_k_categorical_accuracy: 0.9987 - val_loss: 1842.1553 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 53/90
# 7/7 [==============================] - 48s 7s/step - loss: 2756.7002 - accuracy: 0.1000 - top_k_categorical_accuracy: 1.0000 - val_loss: 1429.6346 - val_accuracy: 0.1550 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 54/90
# 7/7 [==============================] - 48s 7s/step - loss: 2983.3906 - accuracy: 0.1050 - top_k_categorical_accuracy: 1.0000 - val_loss: 1326.3036 - val_accuracy: 0.1550 - val_top_k_categorical_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 55/90
# 2/7 [=======>......................] - ETA: 21s - loss: 2612.6030 - accuracy: 0.1094 - top_k_categorical_accuracy: 1.0000
